# %% [markdown]
#                     Compiled By Alem Fitwi
#                     January, 2020

# %% [markdown]
# # Software Testing
#
# - In general, **provisioning** means "providing" or making something available. The term is used in a variety of contexts in IT. For example, in grid computing, to provision is to activate a grid component, such as a server, array, or switch, so that it is available for use. In a storage area network (SAN), storage provisioning is the process of assigning storage to optimize performance. In telecommunications terminology, provisioning means providing a product or service, such as wiring or bandwidth.
#
# - **Provisioning** means slightly different things in different aspects of telecommunications:
#     1. Providing telecommunications service to a user, including everything necessary to set up the service, such as equipment, wiring, and transmission.
#
#     2. Used as a synonym for configuring, as in "Telecommunications lines must be correctly provisioned to work with the customer's equipment and enabled for various options the customer has chosen."
#
#     3. In a traditional telecommunications environment, there are three separate types of provisioning: circuit provisioning, service provisioning, and switch provisioning.
#
#     4. In a wireless environment, provisioning refers to service activation and involves programming various network databases with the customer's information.
#
#     5. In a slightly different sense, network provisioning systems are intermediary systems that are used to provide customer services, log transactions, carry out requests, and update files.
#
#     6. Provisioning is the fourth step of the telecommunications sequence called OAM&P: Operations, Administration, Maintenance, and Provisioning.
#
#     7. According to the technical group that created the Services Provisioning Markup Language (SPML), provisioning is "the automation of all the steps required to manage (setup, amend, and revoke) user or system access entitlements or data relative to electronically published services."
#
# - **Software Provisioning**
#     - When we say “software provisioning,” we usually think about the deployment part of software delivery. But the full provisioning process also includes environments provisioning as well as promotion process between environments. On top of that, testing, quality assurance, and reporting are also part of software provisioning
#
# - **Development, Test, QA, and Production Environments**
#     - A Development environment is where you configure, customize, and use source control to build an image of the Waveset application to be promoted to another environment. You also write an upgrade procedure in this environment that you follow in each target environment.
#     - A Test environment is where you test your upgrade procedure against controlled data and perform controlled testing of the resulting Waveset application.
#     - A QA environment is where you test your upgrade procedure against data, hardware, and software that closely simulate the Production environment and where you allow intended users to test the resulting Waveset application.
#     - A Production environment is where the Waveset application is actually available for business use.

# %% [markdown]
# # 1. What is Software Testing(SWT)?
# - Software: a program that makes a computer behave in a certain way. A set of isntructs that instruct the computer to perform certain taks for users.
#     - System Software: Runs or operates the computers
#     - Application: Helps users make use of computers
#
# - Customers question the QA of a company when the quality of a company's product is of low quality or defective.
# - SWT is, therefore, the act of examining the artifacts and the behavior of the software under test by validation and verification to ensure that it works as required and designed.
# - Verification:
#     - the process of checking that a software achieves its goal without any bugs.
#     - It is the process to ensure whether the product that is developed is right or not.
#     - It verifies whether the developed product fulfills the requirements that we have.
#     - Verification is static testing.
#     - Verification means are we building the product right?
#
# - Validation:
#     - the process of checking whether the software product is up to the mark or in other words product has high level requirements.
#     - It is the process of checking the validation of product i.e. it checks whether what we are developing is the right product. It is validation of actual and expected product.
#     - Validation is the dynamic testing.
#     - Validation means are we building the right product?

# %% [markdown]
# # 2. What is Manual Testing?
#
# - SWT done manually without the help of any test automation tools.
# - Manual vs Automated Testing
# - Manual Testing:
#     1. Analyze The Requirements
#     2. Test Planning
#     3. Testcase Creation
#     4. Test Execution
#         - $\rightarrow$ Passed
#         - $\rightarrow$ PFailed  $\rightarrow$ Deffects/Bugs
#     5. Test Reports

# %% [markdown]
# # 3. Objectives of Software Testing
# 1. To find defects/prevent defects
# 2. To ensure the product is of good quality
# 3. To ensure the SW Meets The Product Requirements
# 4. To ensure SW is fit for use

# %% [markdown]
# # 4. Importance of Software Testing
# - Why is SWT necessary?
#     - Impacts loss of money (helps avoid loss of money)
#     - Improves Product Quality
#     - Reduces Risk (software used in airplane --> financial and life risks)

# %% [markdown]
# # 5. Seven Principles of Software Testing
#
# Requirement Analysis $\rightarrow$ Design $\rightarrow$ Coding $\rightarrow$ Testing $\rightarrow$ Deployment $\rightarrow$ UAT
#
# 1. Early Testing (During Development)
# 2. Testing Shows Presence Defects. But it can never fully prove the abscence of defects. You can only say it is defect free based on your testcases. Yoou can never claim it is defect free.
# 3. Exhaustive Testing is not possible: you cannot test all possible combinations. It is all about strategizing!
# 4. Defect Clustering: If there are defects in some modules, it is likely that there are more defects in those modules.
# 5. Pesticide paradox: They use the same pesticide now and then and it stops working. The pests become used to it. Likewise, if you are using the same tescase now and then, it might not help you uncover the defects.
# 6. Testing is context Dependent: varies depending on the area of application.
# 7. Absence of Error Fallacy: requirements are verified but product is not fit for use.

# %% [markdown]
# # 6. Software Development Life Cycle (SDLC)
# - Set of processes pursued to develop a software
#     1. Requirement Analysis
#     2. Design
#     3. Development
#     4. Testing
#     5. Deployment/Production
#     6. Maintenance
# - Models:
#     - Waterfall Model
#     - V Model
#     - Iterative Model
#     - Agile Model

# %% [markdown]
# # 7. Software Testing Life Cycle (STLC)
# 1. Requirement Analysis
# 2. Test Planning
# 3. Testcases design and development/creation
# 4. Test Env't Setup
# 5. Test Execution
# 6. Test Reporting
# 7. Test Closure.

# %% [markdown]
# # 8. Waterfall Model in Software Engineering
#
#         user Requirement Analysis: From Customer --> signed
#                 Global Design
#                         Detailed Design
#                                 Coding
#                                       Testing
#                                              Deployment
#                                                        Maintenance
# - Cost of defect is very high because testing is done after full development. Plus, the development time is very long.

# %% [markdown]
# # 9. V Model in Software Engineering
#
#     Requirement                                            UAT
#         System Analysis & Design                    System Testing
#             Global Design- HLD                 Integration Testing
#                 Detailed Design-LLD        Unit Testing
#                                     Coding
# - Testing is done phase wise; however the development/delivery time is long.

# %% [markdown]
# # 10. Iterative Model in Software Engineering
# - SW should be delivered very quickly and matured in multiple phases
# - Phase-I:  Requirement $\rightarrow$ Design $\rightarrow$ Coding $\rightarrow$ Testing $\rightarrow$ Deployment $\rightarrow$ UAT
# - Phase-II:  Requirement $\rightarrow$ Design $\rightarrow$ Coding $\rightarrow$ Testing $\rightarrow$ Deployment $\rightarrow$ UAT
# - Phase-III:  Requirement $\rightarrow$ Design $\rightarrow$ Coding $\rightarrow$ Testing $\rightarrow$ Deployment $\rightarrow$ UAT
# - ...
# - Shorter Development/Delivery Cycle: one to two months.
# - Similar to **Agile** but not the same.

# %% [markdown]
# # 11. Levels in Software Testing
# 1. Unit Testing
# 2. Integration Testing
# 3. System (E2E) Testing (ST, SIT)
# 4. User Acceptance Testing (UAT)

# %% [markdown]
# ## 11.1 Unit Testing/Component Testing
# - Component Testing
#     - Method/Function
#     - Module
# - Units are tested independently
# - Example --> E-Commerce Website:
#     - Login
#     - Dashboard
#     - Products
#     - Checkout

# %% [markdown]
# ## 11.2 Integration Testing
# - Interface Testing of multiple units
#     - Src code vs DB

# %% [markdown]
# ## 11.3 System Testing
# - A black box test that covers the whole system of units.
# - A complete system with known inputs and outputs

# %% [markdown]
# ## 11.4 User Acceptance Testing?
# - Verify the needs/requirements of a customer --> AT
#     - Alpha Testing: Happens @Dvt Premises internally
#     - Beta Testing: Happens @Customer Premises externally
# - Make sure contractual, regulatory, ... requirements are met.

# %% [markdown]
# # 12. Types of Software Testing
#
# - **Functional Testing**: Tests the features or functionaly of the software whether properly working or not.
#     1. unit Testing
#     2. Integration Testing
#     3. System Testing
#     4. Acceptance Tesing
#     5. Regression Testing
#     6. Sanity Testing
#     7. Smoke Testing
#     8. Usability Testing
#
# - Summary of FT:
#     - Checks functionality or requirements
#     - Validates functional aspects of the SW
#     - Focuses on user requirements
#     - Can be easily done manually
#     - Types:
#         - Unit Testing
#         - Integration Testing
#         - System Testing
#         - UAT
#         - Regression Testing
#
# - **Non-functional Testing**: Testing of non-functional aspects of the software that deals with response time (Responsiveness), stability (heavy load condition) security/privacy, whether the SW runs on all platforms or not,
#     1. Performance Testing: Response time, processing time, concurrency (concurrent user volum), throughput, ...
#     2. Load Testing:
#     3. Stress Testing
#     4. Scalibility Testing
#     5. Recovery Testing
#     6. Compatibility Testing
#     7. Security Testing
# - Summary of NFT:
#     - Checks the performance of the specific functionality
#     - Validates non-functional aspects of the SW
#     - Focuses on NFR, or user expectation
#     - Very difficult to manually do; needs to be automated
#     - Types:
#         - Load Testing
#         - Stress Testing
#         - Spike Testing
#         - Volume Testing

# %% [markdown]
# ## 12.1 Regression Testing
#
# - The most widely done software testing in any software development.
# - Makes sure any of the existing functionalities haven't been broken by changes introduced.
# - Done when:
#     - A new feature/functionality is added
#     - A bug/defect-fix is made
#     - A code change/refactoring (to improve performance or maintainability) is made
#     - A config change is made.
# - Done to make sure that the existing functionalities or features are okay every time a new feature or bug-fix is made.
# - Uses past results as a source of truth.
# - Not the same as re-testing; but it makes use of re-testing
# - Techniques of Regression Testing:
#     - Select All Testcases: Requires a lot of effort unless the process is automated.
#     - Regression Test Selection: focus on areas where changes were made.
#     - Prioritizing: prioritize the critical functionalities. Then, in case of any change, they are tested.
#
# - How To Select The Regression Test Techniques? Criterias:
#     - Frequently Used Functionalities
#     - High Priority Functionalities or Testcases: Pick all the high priority testcases.
#     - Integration Testcases: Whenever there is a change in the interfaces, consider these testcases in the RT.
#     - As per module: If module was impacted, include it in the RT.
#
# **Regression Testing in Agile Development**:
# - Agile: Scrum is a two-three weeks development
#     - Sprint-1: 2 weeks $\rightarrow$ RT
#         - S1 ..4TCs, S2...5TCs, S3 ..7TCs, S4 .. 10TCs, ... Stories/functionalities
#     -  Sprint-2: 2 weeks $\rightarrow$ RT
#     -  Sprint-3: 2 weeks $\rightarrow$ RT
# - It becomes hard to handle RT manually; the best way to tackle it us automation.

# %% [markdown]
# https://www.oreilly.com/library/view/programming-python-second/0596000855/ch04s04.html

# %%
#!/usr/local/bin/python
import os, sys                            # get unix, python services 
from stat import ST_SIZE                  # or use os.path.getsize
from glob import glob                     # file name expansion
from os.path import exists                # file exists test
from time import time, ctime              # time functions

print 'RegTest start.' 
print 'user:', os.environ['USER']         # environment variables
print 'path:', os.getcwd(  )              # current directory
print 'time:', ctime(time(  )), '\n'
program = sys.argv[1]                     # two command-line args
testdir = sys.argv[2]

for test in glob(testdir + '/*.in'):      # for all matching input files
    if not exists('%s.out' % test):
        # no prior results
        os.system('%s < %s > %s.out 2>&1' % (program, test, test))
        print 'GENERATED:', test
    else: 
        # backup, run, compare
        os.rename(test + '.out', test + '.out.bkp')
        os.system('%s < %s > %s.out 2>&1' % (program, test, test))
        os.system('diff %s.out %s.out.bkp > %s.diffs' % ((test,)*3) )
        if os.stat(test + '.diffs')[ST_SIZE] == 0:
            print 'PASSED:', test 
            os.remove(test + '.diffs')
        else:
            print 'FAILED:', test, '(see %s.diffs)' % test

print 'RegTest done:', ctime(time(  ))

# %% [markdown]
# ### Regression Testing Revisited
# https://www.guru99.com/regression-testing.html
#
# - **What is Regression Testing?**
# - Regression Testing is defined as a type of software testing to confirm that a recent program or code change has not adversely affected existing features. Regression Testing is nothing but a full or partial selection of already executed test cases that are re-executed to ensure existing functionalities work fine.
# - This testing is done to ensure that new code changes do not have side effects on the existing functionalities. It ensures that the old code still works once the latest code changes are done.
#
# - **Why Regression Testing?**
# - There is a need for regression testing whenever the code is changed, and you need to determine whether the modified code will affect other parts of the software application. Moreover, regression testing is needed when
#     - a new feature is added to the software application.
#     - a functional or performance defect/issue is fixed.
#
# **How to do Regression Testing**
# - In order to do Regression Testing process, we need to first debug the code to identify the bugs. Once the bugs are identified, required changes are made to fix it, then the regression testing is done by selecting relevant test cases from the test suite that covers both modified and affected parts of the code.
# - Software maintenance is an activity which includes enhancements, error corrections, optimization and deletion of existing features. These modifications may cause the system to work incorrectly. Therefore, **Regression Testing becomes necessary**. Regression Testing can be carried out using the following techniques:
#     - Rgression Testing:
#         - Retest All
#         - Regression Test Selection
#         - Prioritization of Test Cases
#
# - **Retest All**
#     - This is one of the methods for Regression Testing in which all the tests in the existing test bucket or suite should be re-executed. This is very expensive as it requires huge time and resources.
#
# - **Regression Test Selection**
#     - Regression Test Selection is a technique in which some selected test cases from test suite are executed to test whether the modified code affects the software application or not. Test cases are categorized into two parts, reusable test cases which can be used in further regression cycles and obsolete test cases which can not be used in succeeding cycles.
#
# - **Prioritization of Test Cases**
#     - Prioritize the test cases depending on business impact, critical & frequently used functionalities. Selection of test cases based on priority will greatly reduce the regression test suite.
#
# - **Selecting test cases for regression testing**
#     - It was found from industry data that a good number of the defects reported by customers were due to last minute bug fixes creating side effects and hence selecting the Test Case for regression testing is an art and not that easy.  Effective Regression Tests can be done by selecting the following test cases –
#         - Test cases which have frequent defects
#         - Functionalities which are more visible to the users
#         - Test cases which verify core features of the product
#         - Test cases of Functionalities which has undergone more and recent changes
#         - All Integration Test Cases
#         - All Complex Test Cases
#         - Boundary value test cases
#         - A sample of Successful test cases
#         - A sample of Failure test cases
#
# - **Regression Testing Tools**
#     - If your software undergoes frequent changes, regression testing costs will escalate. In such cases, Manual execution of test cases increases test execution time as well as costs. Automation of regression test cases is the smart choice in such cases.  The extent of automation depends on the number of test cases that remain re-usable for successive regression cycles.
#     - Following are the most important tools used for both functional and regression testing in software engineering:
#         1. testRigor
#         2. Avo Assure
#         3. Subject7
#         4. Selenium
#         5. Quick Test Professional (QTP)
#         6. Rational Functional Tester (RFT)
#
# - **Regression Testing and Configuration Management**
#     - Configuration Management during Regression Testing becomes imperative in Agile Environments where a code is being continuously modified. To ensure effective regression tests, observe the following :
#         - Code being regression tested should be under a configuration management tool
#         - No changes must be allowed to code, during the regression test phase.  Regression test code must be kept immune to developer changes.
#         - The database used for regression testing must be isolated. No database changes must be allowed
#
# - **Difference between Re-Testing and Regression Testing**
#     - Retesting means testing the functionality or bug again to ensure the code is fixed. If it is not fixed, Defect needs to be re-opened. If fixed, Defect is closed.
#     - Regression testing means testing your software application when it undergoes a code change to ensure that the new code has not affected other parts of the software.
#     - Also, Check out the complete list of differences over here.
#
# - **Challenges in Regression Testing**
#     - Following are the major testing problems for doing regression testing:
#         - With successive regression runs, test suites become fairly large.  Due to time and budget constraints, the entire regression test suite cannot be executed
#         - Minimizing the test suite while achieving maximum Test coverage remains a challenge
#         - Determination of frequency of Regression Tests, i.e., after every modification or every build update or after a bunch of bug fixes, is a challenge.
#
# - **Conclusion**
#     - Regression Testing Meaning – Regression testing is a type of software testing that ensures an application still functions as expected after improvements, any code changes, or updates.
#     - An effective regression strategy, save organizations both time and money. As per one of the case study in banking domain, regression saves up to 60% time in bug fixes(which would have been caught by regression tests) and 40%  in money

# %% [markdown]
# ## 12.2 Retesting vs Regression
# - Scenario: Module-Login --> for FB, Google, Twitter, and Email tested 10 times for each. For FB, it failed twice. The rest of all tests passed.
#     - Retesting Testing:
#         - The Execution of only failed testcases to validate that they have been properly fixed.
#         - Only the two failed testcases of FB are re-tested after fix to make sure they were properly fixed.
#         - Retesting is also performed when a new feature is added to a certain functionality or module to validate it.
#     - Regression Testing:
#         - However, regression testing is performed on the FB, Google, Twitter, and Email testcases.
#         - Testcases can be reduced to the critical ones if need be.
#         - Not only the failed testcases/features but also the surrounding features are also tested.
#         - Has retesting (re-executing) within it

# %% [markdown]
# ## 12.3 Smoke Testing Vs Sanity Testing
# - Related to the SW Builds
# - **Smoke Testing**:
#     - Smoke Testing Comes the smoke testing plumbers to find a leak. They inject a smoke at one end and check if there is a leakage in between point of injection and end.
#     - Apply smoke testing to sw by running the key functionalities (critical testcases) on the sw build-x. It is shallow approach that happens when the build in early unstable phase.
#     - Smoke testing is done before a detailed test.
#     - checks if critical functions are still working
#     - verify stability before rigorous testing
#     - tests cover most components
#     - General health checkup
# - **Sanity Testing**:
#     - Deep Testing of a certain fix or new feature. Whereas RT is done on the whole surrounding of the fix.
#     - checks new functions or bugs that have been fixed
#     - verify rationality before more rigorous testing
#     - Test covers new components or problematic components
#     - Specialized health checkup

# %% [markdown]
# # 13. Black Box Testing
# - Testing a software w/o any internal knowledge of the SW.
# - Only Inputs and Outputs of the software are known to you.
# - You really dunno what happens inside the product or software
#
#         I/P--->[Black Box] ---> O/P
#
# - System/E2E Testing is an example of Black Box Testing.
# - Not concerned about how implementation was done; only concerned whether correct outputs are produced for some testcases.
# - No knowledge of inetrnal functionalities; only outputs are verified based on inputs.
# - Summary:
#     - Done by SW Testers
#     - Internal code not known
#     - Functional Testing
#     - No programming knowledge required
#     - Types:
#         - Regression Testing
#         - System Testing
#         - Acceptance Testing

# %% [markdown]
# # 14. White Box Testing
# - Testing a product/software with knowledge of its interanl details.
# - The product Details is known to the tester
#         I/P--->[White Box, Implementation is known] ---> O/P
#
# - Unit Testing and Integration testing are typical examples
# - Need understanding of What happens inside the box: classes, methods, ...
# - Class Box Testing
# - Clear Box Testing
# - Structural Testing
# - Summary:
#     - Mostly Done by SW Developers
#     - Knowledge of Internal code implementation required.
#     - Structural (or white box) Testing
#     - Requires programming knowledge
#     - Types:
#         - Unit Testing
#         - Integration Testing
#         - Statements, conditions, and branches/loops are covered.

# %% [markdown]
# # 15. Verification and Validation in Software Testing
# - Verification: Static Testing
#     1. Process of checking documents manually (SRS, Plans, designs, code, ...)
#     2. It doesn't involve the execution of the code but code review to check if best practices and coding practices are followed.
#     3. Find bugs/defects in early cycles
#     4. Cost of defects is less
#     5. Few Types of testing are:
#         - Reviews
#         - Tech Reviews
#         - Walkthrough
#         - Inspection
#         - COde Review
# - Validation: Dynamic Testing
#     1. Testing the product functionality by executing the SW
#     2. Involves code execution to validate the functionality
#     3. Finds bugs/defects during dynamic testing phase
#     4. Cost of defects is high
#     5. Few types of testing are:
#         - Unit Testing
#         - Integration Testing
#         - System Testing
#         - Acceptance Testing
#         - Regression Testing

# %% [markdown]
# # 16. End to End (E2E) Testing in Software Testing
# - Testing the SW or product from start to finish based on the business model/logic implemented into the application in terms of end-user perspective.
# - Test it the way the customers would react
# - Prototype in end-user scenarios --> put yourself in the customers shoes.

# %% [markdown]
# # 17. Exploratory Testing
# - Explore the SW and then write testcases based your findings
# - Useful in uncovering defects that would be missed by tranditional approaches
# - Usecase:
#     - Time Limit --> Use ET to check/test the SW
#     - Early Feedback --> no wait until E2E testing
#     - Find New Testcases --> missed in the structural approach
# - Ways to do ET:
#     - Bug Classification --> Based on the modules in which they occur after running a structure testing.
#     - Test Charter --> Details of what you want to test and how along with timing
#     - Time Box--> State when to fix them
#     - Review Results

# %% [markdown]
# # 18. Testcase
#
# ### 18.1 What is Testcase?
# - In software engineering, a test case is a specification of the inputs, execution conditions, testing procedure, and expected results that define a single test to be executed to achieve a particular software testing objective.
#
# - Common/Mandatory Components:
#     1. Title: "Verify Successful Login with valid Email Account"
#     2. Description: Describe the testcase
#     3. Prerequisite: State prerequisite like user should be registered first
#     4. Test Data: Username and password
#     5. Test Steps: state the steps that need to be followed like launch website, enter your username and password, ...
#     6. Expected Result
#
# - Importance:
#     - Traceability
#     - Coverage: verify whether requirements have been covered by the testcases
#     - Reusability
#
# ### 18.2 Test Scenario vs Testcases
# - Scenario --> Highlevel and one liner
# - Testcase --> Detailed test specs
# - Scenaro --> one or more testcases
# - Scenario-1 --> Testcases
# - Scenario-2 --> Testcases
# - Example: based on user story
#     - Scenario-1: Register with Email
#     - Scenario-2: Register with Google
#     - Scenario-2: Register with FB
#     - Scenario-2: Register with Twitter
# - One liner scenario: Customer should be able to purchase items successfully from e-commerce website A
#     - Register on A --> Testcase
#     - Login to A --> Testcase
#     - Add Item to cart --> Testcase
#     - Proceed To checkout --> Testcase
#     - Make Payment --> Testcase
#     - Do Confirmation --> Testcase
#
# ### 18.3 How to Write Testcases?
#
#     TC ID   TC_0001
#     Created By: Alem
#     Reviewed By: Fitwi
#     Review Date:
#     Priority:
#     Prerequisite:
#
#     Title:
#     Description:
#     Executed By:
#     Execution Date:
#
#     Step #  Test Step Test Date ExpectedResult ActualResult ExecutionDetail(Pass/Fail/Blocked/OnHold) Comments

# %%
from IPython.display import Image
Image("testcase.png")

# %% [markdown]
# ### 18.4 Different Test Design Technique
# - Static:
#     - Reviews
#     - Walk Through
#     - Tech Reviews
#     - Inspection
#     - Static Code Analysis
#     - Data Flow/Control Flow
#
# - Dynamic:
#     - Black Box
#         - Equivalent Partitioning
#         - Boundary Value Analysis
#         - Decision Table
#         - State Transision
#         - Usecase Testing
#
#     - White Box
#         - Statement
#         - Decision
#         - Condition
#         - Multiple Condition
#
#     - Experience Based
#         - Exploratory Testing
#         - Regression Testing

# %% [markdown]
#                          ~END~
